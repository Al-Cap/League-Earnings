# %%
import requests
import numpy as np
import pandas as pd
import json
from bs4 import BeautifulSoup

url = 'https://statsapi.web.nhl.com/api/v1/teams'
page = requests.get(url)
print(page)

soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# {
#   "copyright" : "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2020. All Rights Reserved.",
#   "teams" : [ {
#     "id" : 1,
#     "name" : "New Jersey Devils",
#     "link" : "/api/v1/teams/1",
#     "venue" : {
#       "name" : "Prudential Center",
#       "link" : "/api/v1/venues/null",
#       "city" : "Newark",
#       "timeZone" : {
#         "id" : "America/New_York",
#         "offset" : -4,
#         "tz" : "EDT"
#       }
#     },
#     "abbreviation" : "NJD",
#     "teamName" : "Devils",
#     "locationName" : "New Jersey",
#     "firstYearOfPlay" : "1982",
#     "division" : {
#       "id" : 18,
#       "name" : "Metropolitan",
#       "nameShort" : "Metro",
#       "link" : "/api/v1/divisions/18",
#       "abbreviation" : "M"
#     },
#     "conference" : {
#       "id" : 6,
#       "name" : "Eastern",
#       "link" : "/api/v1/conferences/6"
# ...

# %%
soup.body.find_all("teams")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-268-024556e38c7b> in <module>
# ----> 1 soup.body.find_all("teams")
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
